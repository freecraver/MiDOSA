# %%
import pandas as pd

nodes_file = "airports.csv"
edges_file = "flights.csv"
processed_nodes_file = "nodes.json"
processed_edges_file = "edges.json"

# %%
nodes_df = pd.read_csv(nodes_file)
#nodes_df['y_lng'] = 250/360 * (180 + nodes_df['LONGITUDE'])
#nodes_df['x_lat'] = 500/180 * (90 - nodes_df['LATITUDE'])
nodes_df.to_json(processed_nodes_file, orient="records")
nodes_df.head()
# Out:
#   IATA_CODE                              AIRPORT         CITY STATE COUNTRY  \
# 0       ABE  Lehigh Valley International Airport    Allentown    PA     USA
# 1       ABI             Abilene Regional Airport      Abilene    TX     USA
# 2       ABQ    Albuquerque International Sunport  Albuquerque    NM     USA
# 3       ABR            Aberdeen Regional Airport     Aberdeen    SD     USA
# 4       ABY   Southwest Georgia Regional Airport       Albany    GA     USA
#
#    LATITUDE  LONGITUDE
# 0  40.65236  -75.44040
# 1  32.41132  -99.68190
# 2  35.04022 -106.60919
# 3  45.44906  -98.42183
# 4  31.53552  -84.19447

# %%
pd.set_option('display.max_columns', 500)

subset_size = 100000
edges_df = pd.read_csv(edges_file, nrows=subset_size)
edges_df.fillna(0)
edges_df['EDGE_ID'] = range(0, len(edges_df))
edges_df.to_json(processed_edges_file, orient="records")
edges_df.head()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
# 3  2015      1    1            4      AA            258      N3HYAA
# 4  2015      1    1            4      AS            135      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  DEPARTURE_TIME  \
# 0            ANC                 SEA                    5          2354.0
# 1            LAX                 PBI                   10             2.0
# 2            SFO                 CLT                   20            18.0
# 3            LAX                 MIA                   20            15.0
# 4            SEA                 ANC                   25            24.0
#
#    DEPARTURE_DELAY  TAXI_OUT  WHEELS_OFF  SCHEDULED_TIME  ELAPSED_TIME  \
# ...

# %%
edges_df.describe()
# Out:
#            YEAR     MONTH            DAY    DAY_OF_WEEK  FLIGHT_NUMBER  \
# count  100000.0  100000.0  100000.000000  100000.000000  100000.000000
# mean     2015.0       1.0       3.733920       4.107310    2240.827980
# std         0.0       0.0       1.815542       2.098451    1818.712658
# min      2015.0       1.0       1.000000       1.000000       1.000000
# 25%      2015.0       1.0       2.000000       2.000000     759.000000
# 50%      2015.0       1.0       4.000000       4.000000    1693.000000
# 75%      2015.0       1.0       5.000000       6.000000    3394.000000
# max      2015.0       1.0       7.000000       7.000000    7438.000000
#
#        SCHEDULED_DEPARTURE  DEPARTURE_TIME  DEPARTURE_DELAY      TAXI_OUT  \
# count        100000.000000    97702.000000     97702.000000  97629.000000
# mean           1306.348280     1326.265614        19.937749     17.155917
# std             482.325506      503.509117        45.843577     10.738373
# ...
